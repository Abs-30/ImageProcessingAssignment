# %% [markdown]
# **Identitiy Transformation**
#
# g(x) = F(x)

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

im = cv.imread('images/jeniffer.jpg', cv.IMREAD_GRAYSCALE)
assert im is not None

#image transform formula
t = np.arange(0,256).astype('uint8')        #mapping each 256 pints to 256 
fig, ax = plt.subplots()
ax.plot(t)
ax.set_xlabel(r'Input, $f(\mathbf{x})$')
ax.set_ylabel(r'Output, $\mathrm{T}[f(\mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()

#showing image
cv.namedWindow('Image', cv.WINDOW_AUTOSIZE)
cv.imshow('Image', im)
cv.waitKey(0)
image_transform = cv.LUT(im, t)
cv.imshow('Image', image_transform)
cv.waitKey(0)
cv.destroyAllWindows()

# no transformations occur because the transform and the original image are the same thing

# %% [markdown]
# **Negative Transformation**
#
# g(x)=255 - f(x)

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

im = cv.imread('images/jeniffer.jpg', cv.IMREAD_GRAYSCALE)
assert im is not None

#image transform formula
t = np.arange(255, -1, -1).astype('uint8')        #start at 255, going until 0, => in steps of zero
fig, ax = plt.subplots()
ax.plot(t)
ax.set_xlabel(r'Input, $f(\mathbf{x})$')
ax.set_ylabel(r'Output, $\mathrm{T}[f(\mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()

#showing image
cv.namedWindow('Image', cv.WINDOW_NORMAL)
cv.imshow('Image', im)
cv.waitKey(0)
image_transform = cv.LUT(im, t)
cv.imshow('Image', image_transform)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# *test*

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

im = cv.imread('images/jeniffer.jpg', cv.IMREAD_GRAYSCALE)
assert im is not None

#image transform formula
t = np.arange(255, -1, -1).astype('uint8')        #start at 255, going until 0, => in steps of zero
fig, ax = plt.subplots()
ax.plot(t)
ax.set_xlabel(r'Input, $f(\mathbf{x})$')
ax.set_ylabel(r'Output, $\mathrm{T}[f(\mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()

#showing image
cv.namedWindow('Image', cv.WINDOW_NORMAL)
cv.imshow('Image', im)
cv.waitKey(0)
image_transform = cv.LUT(im, t)
cv.imshow('Image', image_transform)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# **Intensity Windowing**

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

im = cv.imread('images/jeniffer.jpg', cv.IMREAD_GRAYSCALE)
assert im is not None

c = np.array([(100,50) , (150,200)])
#Creating the regions


t1 = np.linspace(0, c[0,1],c[0,0] +1 -0).astype('uint8') 
print(len(t1))       #start at 255, going until 0, => in steps of zero
t2 = np.linspace(c[0,1]+1, c[1,1],c[1,0] - c[0,0]).astype('uint8') 
print(len(t2))
t3 = np.linspace(c[1,1] +1, 255,255 - c[1,0]).astype('uint8') 
print(len(t3))

#transform
transform = np.concatenate((t1,t2), axis=0).astype('uint8')
transform = np.concatenate((transform, t3), axis=0).astype('uint8')
print(len(transform))

#fig
fig, ax = plt.subplots()
ax.plot(transform)
ax.set_xlabel(r'Input, $f(\mathbf{x})$')
ax.set_ylabel(r'Output, $\mathrm{T}[f(\mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()

#showing image
cv.namedWindow('Image', cv.WINDOW_NORMAL)
cv.imshow('Image', im)
cv.waitKey(0)
image_transform = cv.LUT(im, transform)
cv.imshow('Image', image_transform)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 101
# 50
# 105
# 256

# %% [markdown]
# **Assignment Q1**

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

#not changed
im = cv.imread('images/jeniffer.jpg', cv.IMREAD_GRAYSCALE)
assert im is not None


c = np.array([(99,99) , (224,224)])
#Creating the regions
c1 = np.array([(99,124),(224,249)])

t1 = np.linspace(0, c[0,1],c[0,0] +1 -0).astype('uint8') 
print(len(t1))       #start at 255, going until 0, => in steps of zero
t2 = np.linspace(125, c1[1,1],c1[0,1] +1 -0).astype('uint8') 
print(len(t2))
t3 = np.linspace(c[1,1] +1, 255,255 - c[1,0]).astype('uint8') 
print(len(t3))

#transform
transform = np.concatenate((t1,t2), axis=0).astype('uint8')
transform = np.concatenate((transform, t3), axis=0).astype('uint8')
print(len(transform))

#fig
fig, ax = plt.subplots()
ax.plot(transform)
ax.set_xlabel(r'Input, $f(\mathbf{x})$')
ax.set_ylabel(r'Output, $\mathrm{T}[f(\mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.grid()
ax.set_aspect('equal')
plt.show()

#showing image
cv.namedWindow('Image', cv.WINDOW_NORMAL)
cv.imshow('Image', im)
cv.waitKey(0)
image_transform = cv.LUT(im, transform)
cv.imshow('Image', image_transform)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# 100
# 125
# 31
# 256

# %% [markdown]
# **Q2 Test**

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

#not changed
im = cv.imread('images/jeniffer.jpg', cv.IMREAD_COLOR)
assert im is not None

im1 = cv.cvtColor(im, cv.COLOR_BGR2HSV)
h_img,s_img,v_img = cv.split(im1)

fig, ax= plt.subplots(1,3, figsize=(10,20))
ax[0].imshow(h_img, cmap="gray")
ax[0].set_title('Hue')
ax[1].imshow(s_img, cmap="gray")
ax[1].set_title('Saturation')
ax[2].imshow(v_img, cmap="gray")
ax[2].set_title('Value')
plt.show()


x= np.linspace(0, 255,256)
a = 1
sigma = 70
Y =  np.exp((-(x-128)**2)/(2*sigma**2))


#Y2 = (a/128)*Y1
#Y = np.add(Y, Y1)
cv.imshow('Image', im)
cv.waitKey(0)
image_transform = cv.LUT(im, Y)
cv.imshow('Image', image_transform)
cv.waitKey(0)
cv.destroyAllWindows()
plt.plot(Y)

# %%
y, x= np.linspace(0, 255, 256), np.linspace(0, 255, 256)
Y, X= np.meshgrid(x,y)

a = 0.1
sigma = 70

Y1 = a * np.exp((-(x-128)**2)/(2*sigma**2))
#Y2 = (a/128)*Y1
#Y = np.add(Y, Y1)
cv.imshow('Image', h_img)
cv.waitKey(0)
image_transform = cv.LUT(im, Y1)
cv.imshow('Image', image_transform)
cv.waitKey(0)
cv.destroyAllWindows()
plt.plot(Y1)

# %% [markdown]
# **Question 4**

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

#not changed
im = cv.imread('images/washed_out_aerial_image.png', cv.IMREAD_GRAYSCALE)
assert im is not None

plt.figure(figsize = [10, 5])
plt.subplot(1, 2, 1)
plt.gca().set_title('Original Histogram')
h = np.zeros(256)
h = [np.sum(im==i) for i in range (256)]
plt.bar(range(256), h)

plt.subplot(1, 2, 2)
plt.gca().set_title('Equalized Histogram')
eh = cv.equalizeHist(im)
plt.hist(eh)
plt.show()

fig, ax= plt.subplots(1,2, figsize=(10,20))
ax[0].imshow(im, cmap="gray")
ax[0].set_title('Original')
ax[1].imshow(eh, cmap="gray")
ax[1].set_title('Transformed')
plt.show()

# %% [markdown]
# **Question 3**
#
# value of $\gamma$ = 0.5

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

im = cv.imread ('images/highlights_and_shadows.jpg', cv.IMREAD_COLOR)
assert im is not None

im_LAB = cv.cvtColor(im, cv.COLOR_BGR2LAB) 

gamma = .5
t = np.array([(i/255.)**gamma*255 for i in range (256)], np.uint8)
g = t[f]

plt.plot(t)
plt.show()

fig, ax = plt.subplots(1,2, figsize=(10,20))
ax[0].imshow(im, cmap="gray")
ax[0].set_title("Original")
ax[1].imshow(g,cmap="gray")
ax[1].set_title("Gamma Corrected")

plt.figure(figsize = [10, 5])
plt.subplot(1, 2, 1)
plt.gca().set_title('Original Histogram')
im_h = cv.calcHist([im],[0],None,[256],[0,256])
plt.plot(im_h)

plt.subplot(1, 2, 2)
plt.gca().set_title('Corrected Histogram')
g_h = cv.calcHist([g],[0],None,[256],[0,256])
plt.plot(g_h)

# %% [markdown]
# **Question 5**

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

#not changed
im = cv.imread('images/jeniffer.jpg', cv.IMREAD_COLOR)
assert im is not None

im1 = cv.cvtColor(im, cv.COLOR_BGR2HSV)
h_img,s_img,v_img = cv.split(im1)

fig, ax= plt.subplots(1,3, figsize=(10,2.5))
fig.suptitle("a. Splitting into HSV regions", fontsize=12)
ax[0].imshow(h_img, cmap="gray")
ax[0].set_title('Hue')
ax[1].imshow(s_img, cmap="gray")
ax[1].set_title('Saturation')
ax[2].imshow(v_img, cmap="gray")
ax[2].set_title('Value')
plt.show()

#Foreground image extractor
lower = np.array([200, 200, 200])
upper = np.array([255, 255, 255])
thresh = cv.inRange(s_img, 15, 230)
kernel = cv.getStructuringElement(cv.MORPH_ELLIPSE, (20,20))
morph = cv.morphologyEx(thresh, cv.MORPH_CLOSE, kernel)
mask = morph
result = cv.bitwise_and(im, im, mask=mask)

fig, ax = plt.subplots(1,3, figsize=(10,2.5))
fig.suptitle("b. Extracting Foreground mask")
ax[0].imshow(im, cmap="gray")
ax[0].set_title("Original")
ax[1].imshow(mask, cmap="gray")
ax[1].set_title("Foreground Mask")
ax[2].imshow(result, cmap="gray")
ax[2].set_title("Foreground Image")
plt.show()

#histogram
cumulative_sum = np.cumsum(result) #cumulative sum

plt.figure(figsize = [10, 2.5])
plt.subplot(1, 2, 1)
plt.gca().set_title('Original Histogram of foreground')
fg_h = cv.calcHist([result],[0],None,[256],[0,256])
plt.plot(fg_h)

plt.subplot(1, 2, 2)
plt.gca().set_title('Corrected Histogram')
result1 = cv.cvtColor(result, cv.COLOR_BGR2GRAY)
eh = cv.equalizeHist(result1)
plt.plot(eh)
plt.show()

#background image
mask1 = 255 - morph
bg_img = cv.bitwise_and(im, im, mask=mask1)
bg_img1 = cv.cvtColor(bg_img, cv.COLOR_BGR2GRAY);
#added image
img1 = cv.addWeighted(bg_img1,0.5, result1,0.5,0.0)

fig, ax = plt.subplots(1,3, figsize=(10,2.5))
fig.suptitle("f. Adding background with equalized")
ax[0].imshow(bg_img, cmap="gray")
ax[0].set_title("Background")
ax[1].imshow(result, cmap="gray")
ax[1].set_title("Foreground")
ax[2].imshow(img1, cmap="gray")
ax[2].set_title("Added Image")
plt.show()
