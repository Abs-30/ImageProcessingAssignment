# %% [markdown]
# **Identitiy Transformation**
#
# g(x) = F(x)

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

im = cv.imread('images/jeniffer.jpg', cv.IMREAD_GRAYSCALE)
assert im is not None

#image transform formula
t = np.arange(0,256).astype('uint8')        #mapping each 256 pints to 256 
fig, ax = plt.subplots()
ax.plot(t)
ax.set_xlabel(r'Input, $f(\mathbf{x})$')
ax.set_ylabel(r'Output, $\mathrm{T}[f(\mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()

#showing image
cv.namedWindow('Image', cv.WINDOW_AUTOSIZE)
cv.imshow('Image', im)
cv.waitKey(0)
image_transform = cv.LUT(im, t)
cv.imshow('Image', image_transform)
cv.waitKey(0)
cv.destroyAllWindows()

# no transformations occur because the transform and the original image are the same thing

# %% [markdown]
# **Negative Transformation**
# g(x)=255 - f(x)

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

im = cv.imread('images/jeniffer.jpg', cv.IMREAD_GRAYSCALE)
assert im is not None

#image transform formula
t = np.arange(255, -1, -1).astype('uint8')        #start at 255, going until 0, => in steps of zero
fig, ax = plt.subplots()
ax.plot(t)
ax.set_xlabel(r'Input, $f(\mathbf{x})$')
ax.set_ylabel(r'Output, $\mathrm{T}[f(\mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()

#showing image
cv.namedWindow('Image', cv.WINDOW_NORMAL)
cv.imshow('Image', im)
cv.waitKey(0)
image_transform = cv.LUT(im, t)
cv.imshow('Image', image_transform)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# *test*

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

im = cv.imread('images/jeniffer.jpg', cv.IMREAD_GRAYSCALE)
assert im is not None

#image transform formula
t = np.arange(255, -1, 5).astype('uint8')        #start at 255, going until 0, => in steps of zero
fig, ax = plt.subplots()
ax.plot(t)
ax.set_xlabel(r'Input, $f(\mathbf{x})$')
ax.set_ylabel(r'Output, $\mathrm{T}[f(\mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()

#showing image
cv.namedWindow('Image', cv.WINDOW_NORMAL)
cv.imshow('Image', im)
cv.waitKey(0)
image_transform = cv.LUT(im, t)
cv.imshow('Image', image_transform)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 23
#      21 cv.imshow('Image', im)
#      22 cv.waitKey(0)
# ---> 23 image_transform = cv.LUT(im, t)
#      24 cv.imshow('Image', image_transform)
#      25 cv.waitKey(0)
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\lut.cpp:368: error: (-215:Assertion failed) (lutcn == cn || lutcn == 1) && _lut.total() == 256 && _lut.isContinuous() && (depth == CV_8U || depth == CV_8S) in function 'cv::LUT'
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
